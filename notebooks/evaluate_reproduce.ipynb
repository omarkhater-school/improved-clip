# %% [markdown]
# # Evaluation Reproducibility

# %% [markdown]
# ### **Introduction**
#
# In this tutorial, we show how to reprdouce the evaluation results after model training.

# %% [markdown]
# ### Evaluation
#
# The following command runs the evaluation script to evaluate the retrieval performance of the trained model on the MSCOCO validation dataset and the zero-shot classification performance on the ImageNet validation dataset. The evaluation command is obtained by appending `--evaluate --checkpoint /path/to/your/checkpoint --zs_dataset imagenet --zs_datafolder /path/to/imagenet/val` to the training command.

# %%
import os

for checkpoint in [22, 23, 24, 25, 26, 27, 28]:
    command = f"""
        python ../main.py \
            --data_path ../datasets  \
            --ann_path ../datasets/clip_train \
            --train_file cc3m_train_subset.json \
            --train_image_root cc3m_subset_100k \
            --output_dir ../output/isogclr_new_radam_eval \
            --init_model True \
            --use_amp True \
            --loss_function isogclr_new \
            --optimizer radam \
            --tau_init 0.01 \
            --sogclr_gamma 0.966 \
            --eta_init 0.03 \
            --sched tanh \
            --no-distributed False \
            --device mps \
            --epochs 1 \
            --evaluate True \
            --checkpoint ../output/isogclr_new_radam/checkpoint_{checkpoint}.pth \
            --zs_dataset imagenet \
            --zs_datafolder ../datasets/imagenet/val \
            --lr 1.64e-4 \
            --weight_decay 3.73e-4 \
            --embed_dim 512 \
            --rho_I 9.96 \
            --rho_T 7.47 \
            --temp 5.85e-2 \
            --wd_temp_net 5.85e-6 \
            --decay_rate 0.5679 \
            --min_lr 1.0e-5 \
            --cooldown_epochs 1 \
            --warmup_epochs 5 \
            --warmup_lr 1.0e-3
        """
    os.system(command)
# Out:
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_22.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_22.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_22.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_22.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.56, 'txt_r5': 34.18, 'txt_r10': 45.9, 'txt_r_mean': 31.546666666666667, 'img_r1': 10.34827462113639, 'img_r5': 25.998640489423806, 'img_r10': 36.53484745491623, 'img_r_mean': 24.293920855158813, 'r_mean': 27.92029376091274}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.514, 'zeroshot_top3': 43.628, 'zeroshot_top5': 49.578, 'zeroshot_top10': 56.62}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:12
# objective value: 18.14075820704546
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_23.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_23.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_23.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_23.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.86, 'txt_r5': 34.58, 'txt_r10': 45.86, 'txt_r_mean': 31.766666666666666, 'img_r1': 10.50821704186493, 'img_r5': 26.29053540725339, 'img_r10': 36.60282298372586, 'img_r_mean': 24.467191810948055, 'r_mean': 28.11692923880736}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.368, 'zeroshot_top3': 43.652, 'zeroshot_top5': 49.524, 'zeroshot_top10': 56.644}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:13
# objective value: 18.24540568062164
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_24.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_24.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_24.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_24.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.72, 'txt_r5': 34.4, 'txt_r10': 45.28, 'txt_r_mean': 31.46666666666667, 'img_r1': 10.512215602383142, 'img_r5': 26.226558438961973, 'img_r10': 36.47886760766124, 'img_r_mean': 24.40588054966879, 'r_mean': 27.93627360816773}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.424, 'zeroshot_top3': 43.706, 'zeroshot_top5': 49.56, 'zeroshot_top10': 56.646}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:14
# objective value: 18.218738534127713
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_25.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_25.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_25.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_25.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.36, 'txt_r5': 34.64, 'txt_r10': 45.56, 'txt_r_mean': 31.52, 'img_r1': 10.432244392018873, 'img_r5': 26.226558438961973, 'img_r10': 36.48686472869767, 'img_r_mean': 24.381889186559505, 'r_mean': 27.95094459327975}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.5, 'zeroshot_top3': 43.754, 'zeroshot_top5': 49.668, 'zeroshot_top10': 56.76}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:14
# objective value: 18.097414797339624
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_26.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_26.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_26.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_26.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.5, 'txt_r5': 34.1, 'txt_r10': 45.12, 'txt_r_mean': 31.24, 'img_r1': 10.412251589427806, 'img_r5': 26.138590107561278, 'img_r10': 36.438882002479104, 'img_r_mean': 24.32990789982273, 'r_mean': 27.784953949911362}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.512, 'zeroshot_top3': 43.744, 'zeroshot_top5': 49.672, 'zeroshot_top10': 56.646}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:14
# objective value: 18.141417196475935
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_27.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_27.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_27.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_27.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.4, 'txt_r5': 34.68, 'txt_r10': 45.44, 'txt_r_mean': 31.506666666666664, 'img_r1': 10.392258786836738, 'img_r5': 26.114598744451996, 'img_r10': 36.52285177336159, 'img_r_mean': 24.343236434883437, 'r_mean': 27.92495155077505}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.472, 'zeroshot_top3': 43.672, 'zeroshot_top5': 49.684, 'zeroshot_top10': 56.572}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:13
# objective value: 18.08808626227891
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_28.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_28.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_28.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_28.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.38, 'txt_r5': 34.46, 'txt_r10': 45.34, 'txt_r_mean': 31.393333333333334, 'img_r1': 10.240313487144627, 'img_r5': 26.054620336678795, 'img_r10': 36.53484745491623, 'img_r_mean': 24.276593759579885, 'r_mean': 27.83496354645661}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.542, 'zeroshot_top3': 43.766, 'zeroshot_top5': 49.632, 'zeroshot_top10': 56.736}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:14
# objective value: 18.054104495714878

# %%
import os

for checkpoint in [15, 16, 17, 18, 19, 20, 21, 29, 30]:
    command = f"""
        python ../main.py \
            --data_path ../datasets  \
            --ann_path ../datasets/clip_train \
            --train_file cc3m_train_subset.json \
            --train_image_root cc3m_subset_100k \
            --output_dir ../output/isogclr_new_radam_eval \
            --init_model True \
            --use_amp True \
            --loss_function isogclr_new \
            --optimizer radam \
            --tau_init 0.01 \
            --sogclr_gamma 0.966 \
            --eta_init 0.03 \
            --sched tanh \
            --no-distributed False \
            --device mps \
            --epochs 1 \
            --evaluate True \
            --checkpoint ../output/isogclr_new_radam/checkpoint_{checkpoint}.pth \
            --zs_dataset imagenet \
            --zs_datafolder ../datasets/imagenet/val \
            --lr 1.64e-4 \
            --weight_decay 3.73e-4 \
            --embed_dim 512 \
            --rho_I 9.96 \
            --rho_T 7.47 \
            --temp 5.85e-2 \
            --wd_temp_net 5.85e-6 \
            --decay_rate 0.5679 \
            --min_lr 1.0e-5 \
            --cooldown_epochs 1 \
            --warmup_epochs 5 \
            --warmup_lr 1.0e-3
        """
    os.system(command)
# Out:
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_15.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_15.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_15.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_15.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:42
# Validation results: {'txt_r1': 14.2, 'txt_r5': 33.26, 'txt_r10': 45.1, 'txt_r_mean': 30.853333333333335, 'img_r1': 10.2323163661082, 'img_r5': 25.49882042464713, 'img_r10': 35.97105042184813, 'img_r_mean': 23.900729070867822, 'r_mean': 27.37703120210058}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 28.94, 'zeroshot_top3': 43.204, 'zeroshot_top5': 49.092, 'zeroshot_top10': 56.13}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:11
# objective value: 17.790772122036067
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_16.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_16.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_16.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_16.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.28, 'txt_r5': 33.52, 'txt_r10': 45.3, 'txt_r_mean': 31.03333333333333, 'img_r1': 10.400255907873166, 'img_r5': 26.134591547043065, 'img_r10': 36.538846015434444, 'img_r_mean': 24.357897823450227, 'r_mean': 27.69561557839178}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.118, 'zeroshot_top3': 43.202, 'zeroshot_top5': 49.158, 'zeroshot_top10': 56.248}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:12
# objective value: 17.932751969291054
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_17.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_17.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_17.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_17.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.24, 'txt_r5': 34.16, 'txt_r10': 45.24, 'txt_r_mean': 31.213333333333335, 'img_r1': 10.356271742172817, 'img_r5': 25.9666520052781, 'img_r10': 36.39889639729697, 'img_r_mean': 24.24060671491596, 'r_mean': 27.726970024124647}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.224, 'zeroshot_top3': 43.592, 'zeroshot_top5': 49.604, 'zeroshot_top10': 56.544}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:13
# objective value: 17.94009058072427
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_18.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_18.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_18.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_18.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.34, 'txt_r5': 34.46, 'txt_r10': 46.1, 'txt_r_mean': 31.633333333333336, 'img_r1': 10.424247270982447, 'img_r5': 26.09460594186093, 'img_r10': 36.45487624455196, 'img_r_mean': 24.324576485798445, 'r_mean': 27.978954909565893}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.144, 'zeroshot_top3': 43.408, 'zeroshot_top5': 49.41, 'zeroshot_top10': 56.59}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:13
# objective value: 17.96941575699415
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_19.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_19.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_19.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_19.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:44
# Validation results: {'txt_r1': 14.54, 'txt_r5': 34.12, 'txt_r10': 45.9, 'txt_r_mean': 31.52, 'img_r1': 10.548202647047063, 'img_r5': 26.178575712743413, 'img_r10': 36.69079131512655, 'img_r_mean': 24.47252322497234, 'r_mean': 27.99626161248617}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.262, 'zeroshot_top3': 43.608, 'zeroshot_top5': 49.61, 'zeroshot_top10': 56.746}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:13
# objective value: 18.116734215682353
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_20.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_20.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_20.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_20.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:44
# Validation results: {'txt_r1': 14.58, 'txt_r5': 33.76, 'txt_r10': 45.48, 'txt_r_mean': 31.27333333333333, 'img_r1': 10.352273181654605, 'img_r5': 26.302531088808028, 'img_r10': 36.71078411771762, 'img_r_mean': 24.455196129393418, 'r_mean': 27.864264731363374}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.412, 'zeroshot_top3': 43.556, 'zeroshot_top5': 49.592, 'zeroshot_top10': 56.588}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:16
# objective value: 18.1147577272182
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_21.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_21.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_21.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_21.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:44
# Validation results: {'txt_r1': 14.82, 'txt_r5': 34.32, 'txt_r10': 45.72, 'txt_r_mean': 31.62, 'img_r1': 10.432244392018873, 'img_r5': 26.006637610460235, 'img_r10': 36.422887760406255, 'img_r_mean': 24.287256587628452, 'r_mean': 27.953628293814226}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.454, 'zeroshot_top3': 43.614, 'zeroshot_top5': 49.54, 'zeroshot_top10': 56.674}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:14
# objective value: 18.235414797339626
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_29.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_29.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_29.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_29.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:44
# Validation results: {'txt_r1': 14.68, 'txt_r5': 34.42, 'txt_r10': 45.38, 'txt_r_mean': 31.493333333333336, 'img_r1': 10.28829621336319, 'img_r5': 26.022631852533088, 'img_r10': 36.54284457595266, 'img_r_mean': 24.28459088061631, 'r_mean': 27.888962106974823}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.504, 'zeroshot_top3': 43.688, 'zeroshot_top5': 49.6, 'zeroshot_top10': 56.772}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:15
# objective value: 18.15743207112106
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_30.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_30.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_30.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_30.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:44
# Validation results: {'txt_r1': 14.34, 'txt_r5': 34.36, 'txt_r10': 45.14, 'txt_r_mean': 31.28, 'img_r1': 10.376264544763885, 'img_r5': 26.006637610460235, 'img_r10': 36.3469151105602, 'img_r_mean': 24.2432724219281, 'r_mean': 27.76163621096405}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.566, 'zeroshot_top3': 43.706, 'zeroshot_top5': 49.596, 'zeroshot_top10': 56.61}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:16
# objective value: 18.09408818158796

# %%
import os

for checkpoint in [23]:
    command = f"""
        python ../main.py \
            --data_path ../datasets  \
            --ann_path ../datasets/clip_train \
            --train_file cc3m_train_subset.json \
            --train_image_root cc3m_subset_100k \
            --output_dir ../output/isogclr_new_radam_eval \
            --init_model True \
            --use_amp True \
            --loss_function isogclr_new \
            --optimizer radam \
            --tau_init 0.01 \
            --sogclr_gamma 0.966 \
            --eta_init 0.03 \
            --sched tanh \
            --no-distributed False \
            --device mps \
            --epochs 1 \
            --evaluate True \
            --checkpoint ../output/isogclr_new_radam/checkpoint_{checkpoint}.pth \
            --zs_dataset imagenet \
            --zs_datafolder ../datasets/imagenet/val \
            --lr 1.64e-4 \
            --weight_decay 3.73e-4 \
            --embed_dim 512 \
            --rho_I 9.96 \
            --rho_T 7.47 \
            --temp 5.85e-2 \
            --wd_temp_net 5.85e-6 \
            --decay_rate 0.5679 \
            --min_lr 1.0e-5 \
            --cooldown_epochs 1 \
            --warmup_epochs 5 \
            --warmup_lr 1.0e-3
        """
    os.system(command)
# Out:
# Args before running the pipeline:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_23.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k')
# Args after manage path:
# Namespace(data_path='../datasets', ann_path='../datasets/clip_train', train_file='../datasets/clip_train/cc3m_train_subset.json', train_image_root='../datasets/cc3m_subset_100k', bert_config='configs/config_bert.json', image_encoder='resnet50', text_encoder='distilbert-base-uncased', image_res=256, embed_dim=512, optimizer='radam', sched='tanh', lr=0.000164, wd_temp_net=5.85e-06, min_lr=1e-05, warmup=True, warmup_lr=0.001, weight_decay=0.000373, decay_rate=0.5679, epochs=1, warmup_epochs=5, cooldown_epochs=1, patience_epochs=5, decay_epochs=3, momentum=0, init_model=True, batch_size_train=128, batch_size_test=128, evaluate=True, val_frequency=2, checkpoint='../output/isogclr_new_radam/checkpoint_23.pth', device='mps', seed=42, world_size=1, dist_url='env://', distributed=False, no_distributed=False, step_size_per_epoch=100, print_freq_per_epoch=100, resume_learning=False, k_test=256, output_dir='../output/isogclr_new_radam_eval', loss_function='isogclr_new', vicreg_sim_coeff=25.0, vicreg_std_coeff=25.0, sogclr_gamma=0.966, rho_I=9.96, rho_T=7.47, eta_init=0.03, tau_init=0.01, rho_init=6, beta_u=0.9, temp=0.0585, learnable_temp=True, personalized_tau=True, store_tau=True, isogclr_temp_net=True, alpha=1.0, use_amp=True, train_frac=1.0, zs_dataset='imagenet', zs_datafolder='../datasets/imagenet/val', val_coco_file='../datasets/clip_train/coco_val.json', coco_image_root='../datasets/mscoco_val/mscoco_val2014_subset_5k', gpu=0)
# ***
# Creating retrieval dataset
# ***
# len of train_dataset: 100000
# len of validation dataset: 5000
# ***
# Creating model
# ***
# Loading model from checkpoint: ../output/isogclr_new_radam/checkpoint_23.pth
# load checkpoint from ../output/isogclr_new_radam/checkpoint_23.pth
# Start Evaluating
# ***
# Starting evaluation
# ***
# Computing features for evaluation...
# Model Retrieval Evaluation time 0:01:43
# Validation results: {'txt_r1': 14.86, 'txt_r5': 34.58, 'txt_r10': 45.86, 'txt_r_mean': 31.766666666666666, 'img_r1': 10.50821704186493, 'img_r5': 26.29053540725339, 'img_r10': 36.60282298372586, 'img_r_mean': 24.467191810948055, 'r_mean': 28.11692923880736}
# starting zeroshot transfer...
# Zero-shot results: {'zeroshot_top1': 29.368, 'zeroshot_top3': 43.652, 'zeroshot_top5': 49.524, 'zeroshot_top10': 56.644}
# Evaluation results logged to ../output/isogclr_new_radam_eval/eval_log.txt
# Overall Evaluation time 0:07:15
# objective value: 18.24540568062164
